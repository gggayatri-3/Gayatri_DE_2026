# %% [markdown]
# #### Python Assignment: Lambda, map(), filter(), reduce(), and Combined Operations

# %% [markdown]
# #### Section 1: Lambda Expression : Question 1: Calculate the square of the number.

# %%
# Section 1: Lambda Expression Question 1
# Calculate the square of the number.

# %%
number = 8
square = lambda x: x**2
print(square(number))
# Out:
# 64

# %% [markdown]
# #### Section 1: Lambda Expression : Question 2: Calculate the cube of the number.

# %%
# Section 1: Lambda Expression Question 2
# Calculate the cube of the number.

# %%
number = 5
cube = lambda x: x**3
print(cube(number))
# Out:
# 125

# %% [markdown]
# #### Section 1: Lambda Expression : Question 3: Add a and b.

# %%
# Section 1: Lambda Expression : Question 3
# Add a and b.

# %%
a = 25
b = 17
add_ab = lambda a, b: a + b
print(add_ab(a, b))
# Out:
# 42

# %% [markdown]
# #### Section 1: Lambda Expression : Question 4: Subtract b from a.

# %%
# Section 1: Lambda Expression : Question 4
# Subtract b from a.

# %%
a = 50
b = 18
subtract = lambda a, b: a - b
print(subtract(a, b))
# Out:
# 32

# %% [markdown]
# #### Section 1: Lambda Expression : Question 5: Multiply a and b.

# %%
# Section 1: Lambda Expression : Question 5
# Multiply a and b.

# %%
a = 12
b = 9
multiply = lambda a, b: a * b
print(multiply(a, b))
# Out:
# 108

# %% [markdown]
# #### Section 1: Lambda Expression : Question 6: Divide a and b.

# %%
# Section 1: Lambda Expression : Question 6
# Divide a and b.

# %%
a = 100
b = 4
divide = lambda a, b: a / b
print(divide(a, b))
# Out:
# 25.0

# %% [markdown]
# #### Section 1: Lambda Expression : Question 7: Find the largest number.

# %%
# Section 1: Lambda Expression : Question 7
# Find the largest number.

# %%
a = 72
b = 91
largest = lambda a, b: a if a > b else b
print(largest(a, b))
# Out:
# 91

# %% [markdown]
# #### Section 1: Lambda Expression : Question 8: Return the smallest number.

# %%
# Section 1: Lambda Expression : Question 8
# Return the smallest number.

# %%
a = 46
b = 28
smallest = lambda a, b: a if a < b else b
print(smallest(a, b))
# Out:
# 28

# %% [markdown]
# #### Section 1: Lambda Expression : Question 9: Return True when the number is even and False otherwise.

# %%
# Section 1: Lambda Expression : Question 9
# Return True when the number is even and False otherwise.

# %%
number = 34
even = lambda number: number % 2 == 0
print(even(number))
# Out:
# True

# %% [markdown]
# #### Section 1: Lambda Expression : Question 10: Return True when the number is odd and False otherwise.

# %%
# Section 1: Lambda Expression : Question 10
# Return True when the number is odd and False otherwise.

# %%
number = 27
odd = lambda number: number % 2 != 0
print(odd(number))
# Out:
# True

# %% [markdown]
# #### Section 1: Lambda Expression : Question 11: Calculate the area of a rectangle.

# %%
# Section 1: Lambda Expression : Question 11
# Calculate the area of a rectangle.

# %%
length = 12
width = 8
area = lambda length, width: length * width
print(area(length, width))
# Out:
# 96

# %% [markdown]
# #### Section 1: Lambda Expression : Question 12: Calculate the area of a circle using 3.14.

# %%
# Section 1: Lambda Expression : Question 12
# Calculate the area of a circle using 3.14.

# %%
radius = 7
area = lambda radius: 3.14 * radius ** 2
print(area(radius))
# Out:
# 153.86

# %% [markdown]
# #### Section 1: Lambda Expression : Question 13: Calculate the perimeter of a rectangle.

# %%
# Section 1: Lambda Expression : Question 13
# Calculate the perimeter of a rectangle.

# %%
length = 15
width = 10
perimeter = lambda length, width: 2 * (length + width)
print(perimeter(length, width))
# Out:
# 50

# %% [markdown]
# #### Section 1: Lambda Expression : Question 14: Convert Celsius into Fahrenheit.

# %%
# Section 1: Lambda Expression : Question 14
# Convert Celsius into Fahrenheit.

# %%
celsius = 35
fahrenheit = lambda celsius: (celsius * 9 / 5) + 32
print(fahrenheit(celsius))
# Out:
# 95.0

# %% [markdown]
# #### Section 1: Lambda Expression : Question 15: Convert Fahrenheit into Celsius.

# %%
# Section 1: Lambda Expression : Question 15
# Convert Fahrenheit into Celsius.

# %%
fahrenheit = 104
celsius = lambda fahrenheit: (fahrenheit * 5 / 9) - 32
print(celsius(fahrenheit))
# Out:
# 25.77777777777778

# %% [markdown]
# #### Section 1: Lambda Expression : Question 16: Return the length of the string.

# %%
# Section 1: Lambda Expression : Question 16
# Return the length of the string.

# %%
word = "Python"
length = lambda x: len(x)
print(length(word))
# Out:
# 6

# %% [markdown]
# #### Section 1: Lambda Expression : Question 17: Return the first character of the string.

# %%
# Section 1: Lambda Expression : Question 17
# Return the first character of the string.

# %%
word = "Azure"
first_char = lambda x: x[0]
print(first_char(word))
# Out:
# A

# %% [markdown]
# #### Section 1: Lambda Expression : Question 18: Return the last character of the string.

# %%
# Section 1: Lambda Expression : Question 18
# Return the last character of the string.

# %%
word = "Databricks"
last_char = lambda x: x[-1]
print(last_char(word))
# Out:
# s

# %% [markdown]
# #### Section 1: Lambda Expression : Question 19: Return the absolute value of the number without using abs().

# %%
# Section 1: Lambda Expression : Question 19
# Return the absolute value of the number without using abs().

# %%
number = -45
absolute_value = lambda x: -x if x < 0 else x
print(absolute_value(number))
# Out:
# 45

# %% [markdown]
# #### Section 1: Lambda Expression : Question 20: Return "Distinction" when marks are 75 or above, "Pass" when marks are 40 to 74,

# %%
# Section 1: Lambda Expression : Question 20
# Return "Distinction" when marks are 75 or above, "Pass" when marks are 40 to 74,
# and "Fail" when marks are below 40.

# %%
number = 72
result = lambda marks: "Distinction" if marks >= 75 else "Pass" if marks >= 40 else "Fail"
print(result(number))
# Out:
# Pass

# %% [markdown]
# #### Section 2: map() : Question 1: Using map() and a lambda expression, calculate the square of every number.

# %%
# Section 2: map() : Question 1
# Using map() and a lambda expression, calculate the square of every number.

# %%
numbers = [1, 2, 3, 4, 5, 6]
square = list(map(lambda x: x ** 2, numbers))
print(square)
# Out:
# [1, 4, 9, 16, 25, 36]

# %% [markdown]
# #### Section 2: map() : Question 2: Using map() and a lambda expression, calculate the cube of every number.

# %%
# Section 2: map() : Question 2
# Using map() and a lambda expression, calculate the cube of every number.

# %%
numbers = [2, 3, 4, 5, 6]
cube = list(map(lambda x: x ** 3, numbers))
print(cube)
# Out:
# [8, 27, 64, 125, 216]

# %% [markdown]
# #### Section 2: map() : Question 3: Using map(), add 5 to every number.

# %%
# Section 2: map() : Question 3
# Using map(), add 5 to every number.

# %%
numbers = [10, 20, 30, 40, 50]

def add_five(number):
    return number + 5

result = list(map(add_five, numbers))
print(result)
# Out:
# [15, 25, 35, 45, 55]

# %% [markdown]
# #### Section 2: map() : Question 4: Using map(), subtract 10 from every number.

# %%
# Section 2: map() : Question 4
# Using map(), subtract 10 from every number.

# %%
numbers = [15, 25, 35, 45, 55]

def subtract_10(number):
    return number - 10

result = list(map(subtract_10, numbers))
print(result)
# Out:
# [5, 15, 25, 35, 45]

# %% [markdown]
# #### Section 2: map() : Question 5: Using map(), multiply every number by 100.

# %%
# Section 2: map() : Question 5
# Using map(), multiply every number by 100.

# %%
numbers = [1, 5, 10, 15, 20]

def multiply_100(number):
    return number * 100

result = list(map(multiply_100, numbers))
print(result)
# Out:
# [100, 500, 1000, 1500, 2000]

# %% [markdown]
# #### Section 2: map() : Question 6: Using map(), convert every name to uppercase.

# %%
# Section 2: map() : Question 6
# Using map(), convert every name to uppercase.

# %%
names = ["ravi", "anil", "meena", "kiran", "sneha"]
result = list(map(str.upper, names))
print(result)
# Out:
# ['RAVI', 'ANIL', 'MEENA', 'KIRAN', 'SNEHA']

# %% [markdown]
# #### Section 2: map() : Question 7: Using map(), convert every name to lowercase.

# %%
# Section 2: map() : Question 7
# Using map(), convert every name to lowercase.

# %%
names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
result = list(map(str.lower, names))
print(result)
# Out:
# ['rahul', 'divya', 'arjun', 'ajay']

# %% [markdown]
# #### Section 2: map() : Question 8: Using map(), convert every name to title case.

# %%
# Section 2: map() : Question 8
# Using map(), convert every name to title case.

# %%
names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
result = list(map(str.title, names))
print(result)
# Out:
# ['Rahul Kumar', 'Anil Sharma', 'Meena Reddy', 'Divya Singh']

# %% [markdown]
# #### Section 2: map() : Question 9: Using map(), calculate the length of every word.

# %%
# Section 2: map() : Question 9
# Using map(), calculate the length of every word.

# %%
words = ["Python", "Azure", "Databricks", "Cloud", "AI"]
result = list(map(len, words))
print(result)
# Out:
# [6, 5, 10, 5, 2]

# %% [markdown]
# #### Section 2: map() : Question 10: Using map(), extract the first character of every word.

# %%
# Section 2: map() : Question 10
# Using map(), extract the first character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]

def first_char(word):
    return word[0]

result = list(map(first_char, words))
print(result)
# Out:
# ['P', 'A', 'D', 'L', 'S']

# %% [markdown]
# #### Section 2: map() : Question 11: Using map(), extract the last character of every word.

# %%
# Section 2: map() : Question 11
# Using map(), extract the last character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]

def last_char(word):
    return word[-1]

result = list(map(last_char, words))
print(result)
# Out:
# ['n', 'e', 'r', 'x', 'k']

# %% [markdown]
# #### Section 2: map() : Question 12: Using map(), convert every Celsius temperature into Fahrenheit.

# %%
# Section 2: map() : Question 12
# Using map(), convert every Celsius temperature into Fahrenheit.

# %%
temperatures = [25, 30, 35, 40, 45]

def celsius_to_fahrenheit(c):
    return (c * 9 / 5) + 32

result = list(map(celsius_to_fahrenheit, temperatures))
print(result)
# Out:
# [77.0, 86.0, 95.0, 104.0, 113.0]

# %% [markdown]
# #### Section 2: map() : Question 13: Using map(), calculate 18% GST for every price.

# %%
# Section 2: map() : Question 13
# Using map(), calculate 18% GST for every price.

# %%
prices = [100, 250, 500, 1000, 2500]

def calculate_gst(price):
    return price * 18 / 100

result = list(map(calculate_gst, prices))
print(result)
# Out:
# [18.0, 45.0, 90.0, 180.0, 450.0]

# %% [markdown]
# #### Section 2: map() : Question 14: Using map(), calculate the final price after adding 18% GST.

# %%
# Section 2: map() : Question 14
# Using map(), calculate the final price after adding 18% GST.

# %%
prices = [100, 250, 500, 1000, 2500]

def final_price(price):
    return price + (price * 18 / 100)

result = list(map(final_price, prices))
print(result)
# Out:
# [118.0, 295.0, 590.0, 1180.0, 2950.0]

# %% [markdown]
# #### Section 2: map() : Question 15: Using map(), round every number to two decimal places.

# %%
# Section 2: map() : Question 15
# Using map(), round every number to two decimal places.

# %%
decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]

def round_two(num):
    return round(num, 2)

result = list(map(round_two, decimal_numbers))
print(result)
# Out:
# [12.46, 45.9, 78.12, 100.0]

# %% [markdown]
# #### Section 2: map() : Question 16: Using map(), convert every number into its absolute value.

# %%
# Section 2: map() : Question 16
# Using map(), convert every number into its absolute value.

# %%
values = [-10, 20, -35, 40, -55, 60]
result = list(map(abs, values))
print(result)
# Out:
# [10, 20, 35, 40, 55, 60]

# %% [markdown]
# #### Section 2: map() : Question 17: Using map(), convert every integer into a string.

# %%
# Section 2: map() : Question 17
# Using map(), convert every integer into a string.

# %%
numbers = [10, 20, 30, 40, 50]
result = list(map(str, numbers))
print(result)
# Out:
# ['10', '20', '30', '40', '50']

# %% [markdown]
# #### Section 2: map() : Question 18: Using map(), remove leading and trailing spaces from every name.

# %%
# Section 2: map() : Question 18
# Using map(), remove leading and trailing spaces from every name.

# %%
names = ["  Ravi  ", " Anil", "Meena ", "  Kiran "]
result = list(map(str.strip, names))
print(result)
# Out:
# ['Ravi', 'Anil', 'Meena', 'Kiran']

# %% [markdown]
# #### Section 2: map() : Question 19: Using map(), extract only employee names.

# %%
# Section 2: map() : Question 19
# Using map(), extract only employee names.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]

def get_name(employee):
    return employee["name"]

result = list(map(get_name, employees))
print(result)
# Out:
# ['Rahul', 'Anil', 'Sneha', 'Kiran']

# %% [markdown]
# #### Section 2: map() : Question 20: Using map(), create a new list of dictionaries containing the employee name,
# # original salary, and salary after a 10% increment.

# %%
# Section 2: map() : Question 20
# Using map(), create a new list of dictionaries containing the employee name,
# original salary, and salary after a 10% increment.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]

def salary_increment(employee):
    return {
        "name": employee["name"],
        "original_salary": employee["salary"],
        "salary_after_increment": employee["salary"] * 1.10
    }

result = list(map(salary_increment, employees))
print(result)
# Out:
# [{'name': 'Rahul', 'original_salary': 45000, 'salary_after_increment': 49500.00000000001}, {'name': 'Anil', 'original_salary': 65000, 'salary_after_increment': 71500.0}, {'name': 'Sneha', 'original_salary': 72000, 'salary_after_increment': 79200.0}, {'name': 'Kiran', 'original_salary': 82000, 'salary_after_increment': 90200.00000000001}]

# %% [markdown]
# #### Section 3: filter() : Question 1: Using filter(), extract all even numbers.

# %%
# Section 3: filter() : Question 1
# Using filter(), extract all even numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]

def is_even(num):
    return num % 2 == 0

result = list(filter(is_even, numbers))
print(result)
# Out:
# [12, 56, 34, 78, 100]

# %% [markdown]
# #### Section 3: filter() : Question 2: Using filter(), extract all odd numbers.

# %%
# Section 3: filter() : Question 2
# Using filter(), extract all odd numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]

def is_odd(num):
    return num % 2 != 0

result = list(filter(is_odd, numbers))
print(result)
# Out:
# [45, 67, 89, 23, 91]

# %% [markdown]
# #### Section 3: filter() : Question 3: Using filter(), extract all numbers greater than 50.

# %%
# Section 3: filter() : Question 3
# Using filter(), extract all numbers greater than 50.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]

def greater_than_50(num):
    return num > 50

result = list(filter(greater_than_50, numbers))
print(result)
# Out:
# [67, 89, 56, 91, 78, 100]

# %% [markdown]
# #### Section 3: filter() : Question 4: Using filter(), extract all numbers less than 100.

# %%
# Section 3: filter() : Question 4
# Using filter(), extract all numbers less than 100.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]

def less_than_100(num):
    return num < 100

result = list(filter(less_than_100, numbers))
print(result)
# Out:
# [12, 45, 67, 89, 23, 56, 91, 34, 78]

# %% [markdown]
# #### Section 3: filter() : Question 5: Using filter(), extract all positive numbers.

# %%
# Section 3: filter() : Question 5
# Using filter(), extract all positive numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]

def positive_number(num):
    return num > 0

result = list(filter(positive_number, numbers))
print(result)
# Out:
# [4, 12, 37, 42]

# %% [markdown]
# #### Section 3: filter() : Question 6: Using filter(), extract all negative numbers.

# %%
# Section 3: filter() : Question 6
# Using filter(), extract all negative numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]

def negative_number(num):
    return num < 0

result = list(filter(negative_number, numbers))
print(result)
# Out:
# [-15, -8, -25]

# %% [markdown]
# #### Section 3: filter() : Question 7: Using filter(), remove all zero values.

# %%
# Section 3: filter() : Question 7
# Using filter(), remove all zero values.

# %%
numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]

def remove_zero_values(num):
    return num != 0

result = list(filter(remove_zero_values, numbers))
print(result)
# Out:
# [-15, -8, 4, 12, -25, 37]

# %% [markdown]
# #### Section 3: filter() : Question 8: Using filter(), extract words containing more than five characters.

# %%
# Section 3: filter() : Question 8
# Using filter(), extract words containing more than five characters.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics"]

def more_than_five(word):
    return len(word) > 5

result = list(filter(more_than_five, words))
print(result)
# Out:
# ['python', 'developer', 'analytics']

# %% [markdown]
# #### Section 3: filter() : Question 9: Using filter(), extract names beginning with "A".

# %%
# Section 3: filter() : Question 9
# Using filter(), extract names beginning with "A".

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]

def start_with_a(name):
    return name.startswith("A")

result = list(filter(start_with_a, names))
print(result)
# Out:
# ['Anil', 'Ajay', 'Arjun', 'Akhil']

# %% [markdown]
# #### Section 3: filter() : Question 10: Using filter(), extract names ending with "n".

# %%
# Section 3: filter() : Question 10
# Using filter(), extract names ending with "n".

# %%
names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]

def end_with_n(name):
    return name.endswith("n")

result = list(filter(end_with_n, names))
print(result)
# Out:
# ['Kiran', 'Mohan', 'Arjun', 'Rajan', 'Varun']

# %% [markdown]
# #### Section 3: filter() : Question 11: Using filter(), extract all multiples of 5.

# %%
# Section 3: filter() : Question 11
# Using filter(), extract all multiples of 5.

# %%
numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]

def multiple_of_5(num):
    return num % 5 == 0

result = list(filter(multiple_of_5, numbers))
print(result)
# Out:
# [10, 15, 20, 25, 30, 40, 45, 50]

# %% [markdown]
# #### Section 3: filter() : Question 12: Using filter(), extract numbers divisible by both 3 and 5.

# %%
# Section 3: filter() : Question 12
# Using filter(), extract numbers divisible by both 3 and 5.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]

def divisible_by_3_5(num):
    return num % 3 == 0 and num % 5 == 0

result = list(filter(divisible_by_3_5, numbers))
print(result)
# Out:
# [15, 30, 45, 60, 75]

# %% [markdown]
# #### Section 3: filter() : Question 13: Using filter(), extract all palindrome words.

# %%
# Section 3: filter() : Question 13
# Using filter(), extract all palindrome words.

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]

def is_palindrome(word):
    return word == word[::-1]

result = list(filter(is_palindrome, words))
print(result)
# Out:
# ['madam', 'level', 'radar', 'civic']

# %% [markdown]
# #### Section 3: filter() : Question 14: Using filter(), extract email addresses ending with ".com".

# %%
# Section 3: filter() : Question 14
# Using filter(), extract email addresses ending with ".com".

# %%
emails = [
    "john@gmail.com",
    "rahul@yahoo.com",
    "admin@python.com",
    "support@azure.org",
    "sales@company.com"
]

def is_com_email(email):
    return email.endswith(".com")

result = list(filter(is_com_email, emails))
print(result)
# Out:
# ['john@gmail.com', 'rahul@yahoo.com', 'admin@python.com', 'sales@company.com']

# %% [markdown]
# #### Section 3: filter() : Question 15: Using filter(), extract all CSV files.

# %%
# Section 3: filter() : Question 15
# Using filter(), extract all CSV files.

# %%
files = [
    "sales.csv",
    "employees.xlsx",
    "products.csv",
    "report.pdf",
    "customers.csv",
    "notes.txt"
]

def is_csv_file(file):
    return file.endswith(".csv")

result = list(filter(is_csv_file, files))
print(result)
# Out:
# ['sales.csv', 'products.csv', 'customers.csv']

# %% [markdown]
# #### Section 3: filter() : Question 16: Using filter(), extract employees whose salary is greater than 60000.

# %%
# Section 3: filter() : Question 16
# Using filter(), extract employees whose salary is greater than 60000.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]

def high_salary(employee):
    return employee["salary"] > 60000

result = list(filter(high_salary, employees))
print(result)
# Out:
# [{'name': 'Anil', 'salary': 65000}, {'name': 'Sneha', 'salary': 72000}, {'name': 'Kiran', 'salary': 82000}]

# %% [markdown]
# #### Section 3: filter() : Question 17: Using filter(), extract students who scored more than 80.

# %%
# Section 3: filter() : Question 17
# Using filter(), extract students who scored more than 80.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79}
]

def scored_above_80(student):
    return student["marks"] > 80

result = list(filter(scored_above_80, students))
print(result)
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}]

# %% [markdown]
# #### Section 3: filter() : Question 18: Using filter(), extract products that are currently in stock.

# %%
# Section 3: filter() : Question 18
# Using filter(), extract products that are currently in stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0}
]

def in_stock(product):
    return product["stock"] > 0

result = list(filter(in_stock, products))
print(result)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'stock': 5}, {'name': 'Mouse', 'price': 600, 'stock': 25}, {'name': 'Monitor', 'price': 18000, 'stock': 8}]

# %% [markdown]
# #### Section 3: filter() : Question 19: Using filter(), extract people who are eligible to vote.

# %%
# Section 3: filter() : Question 19
# Using filter(), extract people who are eligible to vote.

# %%
people = [
    {"name": "Rahul", "age": 17},
    {"name": "Anil", "age": 25},
    {"name": "Sneha", "age": 16},
    {"name": "Kiran", "age": 32},
    {"name": "Meena", "age": 18}
]

def eligible_to_vote(person):
    return person["age"] >= 18

result = list(filter(eligible_to_vote, people))
print(result)
# Out:
# [{'name': 'Anil', 'age': 25}, {'name': 'Kiran', 'age': 32}, {'name': 'Meena', 'age': 18}]

# %% [markdown]
# #### Section 3: filter() : Question 20: Using filter(), extract employees who belong to the IT department and are active.

# %%
# Section 3: filter() : Question 20
# Using filter(), extract employees who belong to the IT department and are active.

# %%
employees = [
    {"name": "Rahul", "department": "IT", "active": True},
    {"name": "Anil", "department": "HR", "active": True},
    {"name": "Sneha", "department": "IT", "active": False},
    {"name": "Kiran", "department": "IT", "active": True},
    {"name": "Meena", "department": "Sales", "active": True}
]

def active_it_employee(employee):
    return employee["department"] == "IT" and employee["active"]

result = list(filter(active_it_employee, employees))
print(result)
# Out:
# [{'name': 'Rahul', 'department': 'IT', 'active': True}, {'name': 'Kiran', 'department': 'IT', 'active': True}]

# %% [markdown]
# #### Section 4: reduce() : Imports

# %%
# Import reduce() from functools before using it below.
from functools import reduce

# %% [markdown]
# #### Section 4: reduce() : Question 1: Using reduce(), calculate the sum of all numbers.

# %%
# Section 4: reduce() : Question 1
# Using reduce(), calculate the sum of all numbers.

# %%
numbers = [10, 20, 30, 40, 50]

def add(x, y):
    return x + y

result = reduce(add, numbers)
print(result)
# Out:
# 150

# %% [markdown]
# #### Section 4: reduce() : Question 2: Using reduce(), calculate the product of all numbers.

# %%
# Section 4: reduce() : Question 2
# Using reduce(), calculate the product of all numbers.

# %%
numbers = [2, 3, 4, 5]

def multiply(x, y):
    return x * y

result = reduce(multiply, numbers)
print(result)
# Out:
# 120

# %% [markdown]
# #### Section 4: reduce() : Question 3: Using reduce(), find the maximum number.

# %%
# Section 4: reduce() : Question 3
# Using reduce(), find the maximum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]

def find_max(x, y):
    return x if x > y else y

result = reduce(find_max, numbers)
print(result)
# Out:
# 91

# %% [markdown]
# #### Section 4: reduce() : Question 4: Using reduce(), find the minimum number.

# %%
# Section 4: reduce() : Question 4
# Using reduce(), find the minimum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]

def find_min(x, y):
    return x if x < y else y

result = reduce(find_min, numbers)
print(result)
# Out:
# 12

# %% [markdown]
# #### Section 4: reduce() : Question 5: Using reduce(), combine all strings into one sentence.

# %%
# Section 4: reduce() : Question 5
# Using reduce(), combine all strings into one sentence.

# %%
words = ["Python", " ", "is", " ", "powerful"]

def combine_strings(x, y):
    return x + y

result = reduce(combine_strings, words)
print(result)
# Out:
# Python is powerful

# %% [markdown]
# #### Section 4: reduce() : Question 6: Using reduce(), calculate the total number of characters in all words.

# %%
# Section 4: reduce() : Question 6
# Using reduce(), calculate the total number of characters in all words.

# %%
words = ["Python", "Azure", "Cloud", "AI"]

def total_characters(total, word):
    return total + len(word)

result = reduce(total_characters, words, 0)
print(result)
# Out:
# 18

# %% [markdown]
# #### Section 4: reduce() : Question 7: Using reduce(), calculate the factorial of a number.

# %%
# Section 4: reduce() : Question 7
# Using reduce(), calculate the factorial of a number.

# %%
number = 6
numbers = list(range(1, number + 1))

def multiply(x, y):
    return x * y

result = reduce(multiply, numbers)
print(result)
# Out:
# 720

# %% [markdown]
# #### Section 4: reduce() : Question 8: Using reduce(), calculate the sum of only the even numbers (without a separate filter step).

# %%
# Section 4: reduce() : Question 8
# Using reduce(), calculate the sum of only the even numbers (without a separate filter step).

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = reduce(lambda total, num: total + num if num % 2 == 0 else total, numbers, 0)
print(result)
# Out:
# 280

# %% [markdown]
# #### Section 4: reduce() : Question 9: Using reduce(), calculate the sum of only the odd numbers (without a separate filter step).

# %%
# Section 4: reduce() : Question 9
# Using reduce(), calculate the sum of only the odd numbers (without a separate filter step).

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = reduce(lambda total, num: total + num if num % 2 != 0 else total, numbers, 0)
print(result)
# Out:
# 315

# %% [markdown]
# #### Section 4: reduce() : Question 10: Using reduce(), find the longest word.

# %%
# Section 4: reduce() : Question 10
# Using reduce(), find the longest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]

def find_longest_word(x, y):
    return x if len(x) > len(y) else y

result = reduce(find_longest_word, words)
print(result)
# Out:
# Kubernetes

# %% [markdown]
# #### Section 4: reduce() : Question 11: Using reduce(), find the shortest word.

# %%
# Section 4: reduce() : Question 11
# Using reduce(), find the shortest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]

def find_shortest_word(x, y):
    return x if len(x) < len(y) else y

result = reduce(find_shortest_word, words)
print(result)
# Out:
# AI

# %% [markdown]
# #### Section 4: reduce() : Question 12: Using reduce(), calculate the total salary.

# %%
# Section 4: reduce() : Question 12
# Using reduce(), calculate the total salary.

# %%
salaries = [45000, 65000, 72000, 82000, 55000]

def add_salary(x, y):
    return x + y

result = reduce(add_salary, salaries)
print(result)
# Out:
# 319000

# %% [markdown]
# #### Section 4: reduce() : Question 13: Using reduce(), calculate the total payroll directly from the dictionaries.

# %%
# Section 4: reduce() : Question 13
# Using reduce(), calculate the total payroll directly from the dictionaries.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]

def total_payroll(total, employee):
    return total + employee["salary"]

result = reduce(total_payroll, employees, 0)
print(result)
# Out:
# 319000

# %% [markdown]
# #### Section 4: reduce() : Question 14: Using reduce(), find the employee with the highest salary.

# %%
# Section 4: reduce() : Question 14
# Using reduce(), find the employee with the highest salary.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]

def find_highest_salary(x, y):
    return x if x["salary"] > y["salary"] else y

result = reduce(find_highest_salary, employees)
print(result)
# Out:
# {'name': 'Kiran', 'salary': 82000}

# %% [markdown]
# #### Section 4: reduce() : Question 15: Using reduce(), find the student with the highest marks.

# %%
# Section 4: reduce() : Question 15
# Using reduce(), find the student with the highest marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Rahul", "marks": 95}
]

def find_highest_marks(x, y):
    return x if x["marks"] > y["marks"] else y

result = reduce(find_highest_marks, students)
print(result)
# Out:
# {'name': 'Rahul', 'marks': 95}

# %% [markdown]
# #### Section 4: reduce() : Question 16: Using reduce(), calculate the total stock quantity.

# %%
# Section 4: reduce() : Question 16
# Using reduce(), calculate the total stock quantity.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]

def total_stock(total, product):
    return total + product["stock"]

result = reduce(total_stock, products, 0)
print(result)
# Out:
# 53

# %% [markdown]
# #### Section 4: reduce() : Question 17: Using reduce(), calculate the total inventory value using price x stock.

# %%
# Section 4: reduce() : Question 17
# Using reduce(), calculate the total inventory value using price x stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]

def total_inventory_value(total, product):
    return total + product["price"] * product["stock"]

result = reduce(total_inventory_value, products, 0)
print(result)
# Out:
# 456500

# %% [markdown]
# #### Section 4: reduce() : Question 18: Using reduce(), calculate the total sales amount.

# %%
# Section 4: reduce() : Question 18
# Using reduce(), calculate the total sales amount.

# %%
sales = [12000, 25000, 18000, 45000, 30000, 52000]

def total_sales(total, sale):
    return total + sale

result = reduce(total_sales, sales, 0)
print(result)
# Out:
# 182000

# %% [markdown]
# #### Section 4: reduce() : Question 19: Using reduce(), merge all dictionaries into one dictionary.

# %%
# Section 4: reduce() : Question 19
# Using reduce(), merge all dictionaries into one dictionary.

# %%
dictionaries = [
    {"name": "Rahul"},
    {"age": 30},
    {"department": "IT"},
    {"salary": 65000}
]

def merge_dictionaries(x, y):
    x.update(y)
    return x

result = reduce(merge_dictionaries, dictionaries, {})
print(result)
# Out:
# {'name': 'Rahul', 'age': 30, 'department': 'IT', 'salary': 65000}

# %% [markdown]
# #### Section 4: reduce() : Question 20: Using reduce(), calculate the sum of unique numbers only (without using sum(set(numbers))).

# %%
# Section 4: reduce() : Question 20
# Using reduce(), calculate the sum of unique numbers only (without using sum(set(numbers))).

# %%
numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]

def unique_sum(total, num):
    if num not in total:
        total.append(num)
    return total

result = reduce(unique_sum, numbers, [])
print(sum(result))
# Out:
# 336

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 1: Using filter() and map(): extract all even numbers, then square every even number.

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 1
# Using filter() and map(): extract all even numbers, then square every even number.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]

def is_even(num):
    return num % 2 == 0

def square(num):
    return num ** 2

result = list(map(square, filter(is_even, numbers)))
print(result)
# Out:
# [144, 3136, 1156, 6084, 10000]

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 2: Using filter() and reduce(): extract all odd numbers, then calculate their total sum.

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 2
# Using filter() and reduce(): extract all odd numbers, then calculate their total sum.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]

def is_odd(num):
    return num % 2 != 0

def add(x, y):
    return x + y

result = reduce(add, filter(is_odd, numbers))
print(result)
# Out:
# 315

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 3: Using filter() and map(): extract numbers greater than 50, then multiply every selected number by 2.

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 3
# Using filter() and map(): extract numbers greater than 50, then multiply every selected number by 2.

# %%
numbers = [10, 25, 40, 55, 70, 85, 100]

def greater_than_50(num):
    return num > 50

def multiply_by_2(num):
    return num * 2

result = list(map(multiply_by_2, filter(greater_than_50, numbers)))
print(result)
# Out:
# [110, 140, 170, 200]

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 4: Using filter(), map(), and reduce(): extract positive numbers, square every positive number,
# # then calculate the total sum of the squared values.

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 4
# Using filter(), map(), and reduce(): extract positive numbers, square every positive number,
# then calculate the total sum of the squared values.

# %%
numbers = [-15, 20, -35, 40, 50, -10, 60]

def is_positive(num):
    return num > 0

def square(num):
    return num ** 2

def add(x, y):
    return x + y

result = reduce(add, map(square, filter(is_positive, numbers)))
print(result)
# Out:
# 8100

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 5: Using filter() and map(): extract words containing more than five characters, then convert them to uppercase.

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 5
# Using filter() and map(): extract words containing more than five characters, then convert them to uppercase.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]

def more_than_five_characters(word):
    return len(word) > 5

def to_uppercase(word):
    return word.upper()

result = list(map(to_uppercase, filter(more_than_five_characters, words)))
print(result)
# Out:
# ['PYTHON', 'DEVELOPER', 'ANALYTICS']

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 6: Using filter() and map(): extract names beginning with "A", then convert them to lowercase.

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 6
# Using filter() and map(): extract names beginning with "A", then convert them to lowercase.

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]

def starts_with_a(name):
    return name.startswith("A")

def to_lowercase(name):
    return name.lower()

result = list(map(to_lowercase, filter(starts_with_a, names)))
print(result)
# Out:
# ['anil', 'ajay', 'arjun', 'akhil']

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 7: Using filter() and reduce(): extract numbers divisible by both 3 and 5, then calculate their total sum.

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 7
# Using filter() and reduce(): extract numbers divisible by both 3 and 5, then calculate their total sum.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]

def divisible_by_3_and_5(num):
    return num % 3 == 0 and num % 5 == 0

def add(x, y):
    return x + y

result = reduce(add, filter(divisible_by_3_and_5, numbers))
print(result)
# Out:
# 225

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 8: Using filter() and reduce(): extract palindrome words, then join them into one string separated by " | ".

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 8
# Using filter() and reduce(): extract palindrome words, then join them into one string separated by " | ".

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]

def is_palindrome(word):
    return word == word[::-1]

def join_with_pipe(x, y):
    return x + " | " + y

result = reduce(join_with_pipe, filter(is_palindrome, words))
print(result)
# Out:
# madam | level | radar | civic

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 9: Using filter(), map(), and reduce(): extract temperatures greater than 30C, convert them into Fahrenheit

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 9
# Using filter(), map(), and reduce(): extract temperatures greater than 30C, convert them into Fahrenheit,
# then calculate the average Fahrenheit temperature.

# %%
temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]

def greater_than_30(temp):
    return temp > 30

def to_fahrenheit(temp):
    return (temp * 9 / 5) + 32

def add(x, y):
    return x + y

result = reduce(add, map(to_fahrenheit, filter(greater_than_30, temperatures))) / len(
    list(filter(greater_than_30, temperatures))
)
print(result)
# Out:
# 99.5

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 10: Using filter(), map(), and reduce(): extract prices greater than 1000, apply a 10% discount to each,

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 10
# Using filter(), map(), and reduce(): extract prices greater than 1000, apply a 10% discount to each,
# then calculate the total discounted amount.

# %%
prices = [450, 1200, 2500, 800, 5000, 1500, 7500]

def greater_than_1000(price):
    return price > 1000

def apply_discount(price):
    return price * 0.9

def add(x, y):
    return x + y

result = reduce(add, map(apply_discount, filter(greater_than_1000, prices)))
print(result)
# Out:
# 15930.0

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 11: Using filter() and map(): extract employees earning more than 60000, increase their salary by 10%,

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 11
# Using filter() and map(): extract employees earning more than 60000, increase their salary by 10%,
# and return their names and updated salaries.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000},
    {"id": 105, "name": "Meena", "salary": 55000}
]

def high_salary(employee):
    return employee["salary"] > 60000

def increase_salary(employee):
    return {
        "name": employee["name"],
        "salary": employee["salary"] * 1.10
    }

result = list(map(increase_salary, filter(high_salary, employees)))
print(result)
# Out:
# [{'name': 'Anil', 'salary': 71500.0}, {'name': 'Sneha', 'salary': 79200.0}, {'name': 'Kiran', 'salary': 90200.00000000001}]

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 12: Using filter() and reduce(): extract employees from the IT department, then calculate their total salary.

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 12
# Using filter() and reduce(): extract employees from the IT department, then calculate their total salary.

# %%
employees = [
    {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
    {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
    {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
    {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
    {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
]

def is_it_employee(employee):
    return employee["department"] == "IT"

def total_salary(total, employee):
    return total + employee["salary"]

result = reduce(total_salary, filter(is_it_employee, employees), 0)
print(result)
# Out:
# 199000

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 13: Using filter(), map(), and reduce(): extract active employees, increase each one's salary by 15%,

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 13
# Using filter(), map(), and reduce(): extract active employees, increase each one's salary by 15%,
# then calculate the total updated payroll.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
    {"id": 102, "name": "Anil", "salary": 65000, "active": True},
    {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
    {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
    {"id": 105, "name": "Meena", "salary": 55000, "active": True},
    {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
]

def is_active(employee):
    return employee["active"]

def increase_salary(employee):
    return {
        "id": employee["id"],
        "name": employee["name"],
        "salary": employee["salary"] * 1.15,
        "active": employee["active"]
    }

def total_payroll(total, employee):
    return total + employee["salary"]

result = reduce(
    total_payroll,
    map(increase_salary, filter(is_active, employees)),
    0
)
print(result)
# Out:
# 284050.0

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 14: Using filter() and reduce(): extract students who passed, then find the topper among them.

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 14
# Using filter() and reduce(): extract students who passed, then find the topper among them.

# %%
students = [
    {"name": "Ravi", "marks": 92, "passed": True},
    {"name": "Kiran", "marks": 68, "passed": True},
    {"name": "Meena", "marks": 85, "passed": True},
    {"name": "Ajay", "marks": 48, "passed": True},
    {"name": "Sneha", "marks": 35, "passed": False},
    {"name": "Rahul", "marks": 95, "passed": True}
]

def passed_student(student):
    return student["passed"]

def topper(student1, student2):
    return student1 if student1["marks"] > student2["marks"] else student2

result = reduce(topper, filter(passed_student, students))
print(result)
# Out:
# {'name': 'Rahul', 'marks': 95, 'passed': True}

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 15: Using filter(), map(), and reduce(): extract students scoring more than 70, extract only their marks,

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 15
# Using filter(), map(), and reduce(): extract students scoring more than 70, extract only their marks,
# then calculate the average marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79},
    {"name": "Rahul", "marks": 95}
]

def above_70(student):
    return student["marks"] > 70

def get_marks(student):
    return student["marks"]

def add(total, mark):
    return total + mark

selected_marks = list(map(get_marks, filter(above_70, students)))

total = reduce(add, selected_marks, 0)
average = total / len(selected_marks)

print("Average Marks:", average)
# Out:
# Average Marks: 87.75

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 16: Using filter(), map(), and reduce(): extract products currently in stock, calculate each product's

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 16
# Using filter(), map(), and reduce(): extract products currently in stock, calculate each product's
# inventory value using price x stock, then calculate the total inventory value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0},
    {"name": "SSD", "price": 6500, "stock": 12}
]

def in_stock(product):
    return product["stock"] > 0

def inventory_value(product):
    return product["price"] * product["stock"]

def total_value(total, value):
    return total + value

values = list(map(inventory_value, filter(in_stock, products)))
result = reduce(total_value, values, 0)

print("Total Inventory Value:", result)
# Out:
# Total Inventory Value: 512000

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 17: Using filter(), map(), and reduce(): extract products in the Electronics category, apply a 20% discount,

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 17
# Using filter(), map(), and reduce(): extract products in the Electronics category, apply a 20% discount,
# then calculate the total discounted value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "category": "Electronics"},
    {"name": "Chair", "price": 4500, "category": "Furniture"},
    {"name": "Monitor", "price": 18000, "category": "Electronics"},
    {"name": "Desk", "price": 8500, "category": "Furniture"},
    {"name": "SSD", "price": 6500, "category": "Electronics"}
]

def is_electronics(product):
    return product["category"] == "Electronics"

def apply_discount(product):
    return product["price"] * 0.80  # 20% discount

def total_price(total, price):
    return total + price

discounted_prices = list(map(apply_discount, filter(is_electronics, products)))
result = reduce(total_price, discounted_prices, 0)

print("Total Discounted Value:", result)
# Out:
# Total Discounted Value: 63600.0

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 18: Using filter() and reduce(): extract delivered orders, then calculate the total delivered revenue.

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 18
# Using filter() and reduce(): extract delivered orders, then calculate the total delivered revenue.

# %%
orders = [
    {"order_id": 1001, "amount": 1200, "status": "Delivered"},
    {"order_id": 1002, "amount": 3500, "status": "Pending"},
    {"order_id": 1003, "amount": 8500, "status": "Delivered"},
    {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
    {"order_id": 1005, "amount": 7600, "status": "Delivered"},
    {"order_id": 1006, "amount": 5100, "status": "Pending"}
]

def is_delivered(order):
    return order["status"] == "Delivered"

def total_revenue(total, order):
    return total + order["amount"]

result = reduce(total_revenue, filter(is_delivered, orders), 0)
print("Total Delivered Revenue:", result)
# Out:
# Total Delivered Revenue: 17300

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 19: Using filter(), map(), and reduce(): extract transactions with amount greater than 5000, add 18% GST

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 19
# Using filter(), map(), and reduce(): extract transactions with amount greater than 5000, add 18% GST
# to every selected transaction, then calculate the grand total after GST.

# %%
transactions = [
    {"id": 1, "amount": 1200},
    {"id": 2, "amount": 5200},
    {"id": 3, "amount": 18000},
    {"id": 4, "amount": 2500},
    {"id": 5, "amount": 9600},
    {"id": 6, "amount": 7200}
]

def greater_than_5000(transaction):
    return transaction["amount"] > 5000

def add_gst(transaction):
    return transaction["amount"] * 1.18

def grand_total(total, amount):
    return total + amount

gst_amounts = list(map(add_gst, filter(greater_than_5000, transactions)))
result = reduce(grand_total, gst_amounts, 0)

print("Grand Total After GST:", result)
# Out:
# Grand Total After GST: 47200.0

# %% [markdown]
# #### Section 5: Combined Lambda, map(), filter(), and reduce() : Question 20: Using filter(), map(), and reduce(): extract active salespeople from the South region, calculate a 5%

# %%
# Section 5: Combined Lambda, map(), filter(), and reduce() : Question 20
# Using filter(), map(), and reduce(): extract active salespeople from the South region, calculate a 5%
# incentive for each, build a list with name/sales/incentive, then calculate the total incentive payable.

# %%
sales_records = [
    {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
    {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
    {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
    {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
    {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
    {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
]

def is_active_south(record):
    return record["region"] == "South" and record["active"]

def calculate_incentive(record):
    return {
        "salesperson": record["salesperson"],
        "sales": record["sales"],
        "incentive": record["sales"] * 0.05
    }

def total_incentive(total, record):
    return total + record["incentive"]

selected = list(map(calculate_incentive, filter(is_active_south, sales_records)))

print("Selected Salespeople:")
print(selected)

result = reduce(total_incentive, selected, 0)
print("Total Incentive Payable:", result)
# Out:
# Selected Salespeople:
# [{'salesperson': 'Rahul', 'sales': 45000, 'incentive': 2250.0}, {'salesperson': 'Kiran', 'sales': 82000, 'incentive': 4100.0}, {'salesperson': 'Arjun', 'sales': 98000, 'incentive': 4900.0}]
# Total Incentive Payable: 11250.0
