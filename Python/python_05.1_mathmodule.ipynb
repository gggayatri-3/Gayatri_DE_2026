# %% [markdown]
# # Python Math Module – 30 Coding Questions

# %%
import math

# %%
# Q1. Write a program to calculate the square root of a number using the math module.

#input from the user
num = float(input("Enter a number:"))
print(math.sqrt(num))
# Out:
# 4.795831523312719

# %%
# Q2. Find the cube root of a given number using mathematical operations.

#input from the  user
num = float(input("Enter a number:"))
#calcuate the cube root
cube_root  = num **(1/3)
print(cube_root)
# Out:
# 3.530348335326063

# %%
# Q3. Calculate the factorial of a number using math.factorial().

num = int(input("Enter a number:"))
result = (math.factorial(num)) # math.factoriaol() returns value only when its a "positive interger and 0".
print(result)
# Out:
# 8683317618811886495518194401280000000

# %%
# Q4. Find the GCD (Greatest Common Divisor) of two numbers using math.gcd()

            #input two numbers from user

num1 = int(input("Enter a number :"))
num2 = int(input("Enter a number :"))
num1,num2
result=(math.gcd)(num1,num2)  #math.gcd()is used to find the (Greatest common Divisior) :
print(result)
# Out:
# 1

# %%
# Q5. Find the LCM of two numbers using math.lcm()

            #input two numbers from user
num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
num1 , num2
result = math.lcm(num1 , num2) #math.lcm()  is used to find the (lcm )"least common multiple"
print(result)
# Out:
# 330

# %%
# Q6. Calculate the value of 5 raised to the power of 8 using math.pow()

x = 5
y = 8
result = math.pow(x, y)
print(result)
# Out:
# 390625.0

# %%
# Q7. Find the absolute value of a negative decimal number using math.fabs().

x = -65.2
print(math.fabs(x)) #math.fabs() is used convert a  any negative decimal number or a  negative number into a absolute value or positive value
# Out:
# 65.2

# %%
# Q8. Round a floating-point number up using math.ceil()

num = float(input("Enter a number :"))
result=math.ceil(num) # math.ceil() is used a round up  the value
print(result)
# Out:
# 44

# %%
# Q9. Round a floating-point number down using math.floor()

num = float(input("Enter a number :"))
result = math.floor(num) #  math.floor() is used to round down the value
print(result)
# Out:
# 65

# %%
# Q10. Round a floating-point number to the nearest integer using round()

num = float(input("Enter a number :"))
result = round(num) 
print(result)
# Out:
# 56

# %%
# Q11. Find the remainder of two numbers using math.fmod().

num1 = 10
num2 = 25
result = math.fmod(num1,num2)
print("Remainder : ", result)
# Out:
# Remainder :  10.0

# %%
# Q12. Find the quotient and remainder using divmod().

x = 26
y = 5
Quotient,remainder= divmod(x,y)
print("Quotient :", Quotient)
print("Remainder :" , remainder)
# Out:
# Quotient : 5
# Remainder : 1

# %%
# Q13. Calculate the sine, cosine, and tangent of 45 degrees.

# Convert 45 degrees to radians
angle = math.radians(45)

# Calculate sine, cosine, and tangent
sin_value = math.sin(angle)
cos_value = math.cos(angle)
tan_value = math.tan(angle)

print("Sin(45°) =", sin_value)
print("Cos(45°) =", cos_value)
print("Tan(45°) =", tan_value)
# Out:
# Sin(45°) = 0.7071067811865476
# Cos(45°) = 0.7071067811865476
# Tan(45°) = 0.9999999999999999

# %%
# Q14. Convert an angle from degrees to radians.

# Input angle in degrees
degrees = float(input("Enter angle in degrees: "))

# Convert to radians
radians = math.radians(degrees)

# Display the result
print("Radians =", radians)
# Out:
# Radians = 0.7853981633974483

# %%
# Q15. Find the logarithm (base 10) of a number using math.log10().

Num = 1000
result = math.log10(1000)
print(result)
# Out:
# 3.0

# %%
# Q16. Find the natural logarithm of a number using math.log().

num = 10
result = math.log(num)
print(result)
# Out:
# 2.302585092994046

# %%
# Q17. Calculate e raised to the power of x using math.exp()

x = 2
result = math.exp(x)
print(result)
# Out:
# 7.38905609893065

# %%
# Q18. Find the value of π (pi) and Euler's number (e) from the math module.

print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
# Q19. Find the distance between two points using math.dist().

x = (1, 2)
y = (4, 6)
result = math.dist(x, y)
print(result)
# Out:
# 5.0

# %%
# Q20. Calculate the hypotenuse of a right triangle using math.hypot().

base = 3
height = 4
result = math.hypot(base, height)
print(result)
# Out:
# 5.0

# %%
# Q21. Find the combination (nCr) using math.comb().

n = 6
r = 2
combination_result = math.comb(n, r)
print(combination_result)
# Out:
# 15

# %%
# Q22. Find the permutation (nPr) using math.perm()

n = 6
r = 2
permutation_result = math.perm(n, r)
print(permutation_result)
# Out:
# 30

# %%
# Q23. Check whether a number is finite, infinite, or NaN using math.isfinite(), math.isinf(), and math.isnan()

num = 10
print(math.isfinite(num))
print(math.isinf(num))
print(math.isnan(num))
# Out:
# True
# False
# False

# %%
# Q24. Find the product of all numbers in a list using math.prod().

l = [1, 2, 3, 4]
for i in l:
  print(math.prod(l))
  break
# Out:
# 24

# %%
# Q25. Find the sum of square roots of all numbers in a list.

l = [2, 4, 6, 8]
for i in l:
  print(math.sqrt(i))
# Out:
# 1.4142135623730951
# 2.0
# 2.449489742783178
# 2.8284271247461903

# %%
# Q26. Find the largest integer less than or equal to the square root of a given number.

num_1 = 25
num_2 = 100
if num_1 > num_2:
  print("Largest interger: ", math.sqrt(num_1))
else:
  print("Largest integer :", math.sqrt(num_2))
# Out:
# Largest integer : 10.0

# %%
# Q27. Calculate compound interest using math.pow().

principle = 10000
rate = 2
time = 2
compound_interest = principle * (math.pow((1 + rate / 100), time)) - principle
print(compound_interest)
# Out:
# 404.0

# %%
# Q28. Find the area and circumference of a circle using math.pi.

radius = 5
area = math.pi * radius ** 2
circumference = 2 * math.pi * radius
print(area)
print(circumference)
# Out:
# 78.53981633974483
# 31.41592653589793

# %%
# Q29. Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.

import math

while True:
    print("\n===== Scientific Calculator =====")
    print("1. Square Root")
    print("2. Factorial")
    print("3. Logarithm (base 10)")
    print("4. Power")
    print("5. Sine")
    print("6. Cosine")
    print("7. Tangent")
    print("8. GCD")
    print("9. LCM")
    print("10. Exit")

    choice = int(input("Enter your choice (1-10): "))

    if choice == 1:
        num = float(input("Enter a number: "))
        print("Square Root =", math.sqrt(num))

    elif choice == 2:
        num = int(input("Enter a positive integer: "))
        print("Factorial =", math.factorial(num))

    elif choice == 3:
        num = float(input("Enter a positive number: "))
        print("Log(base 10) =", math.log10(num))

    elif choice == 4:
        base = float(input("Enter base: "))
        exponent = float(input("Enter exponent: "))
        print("Power =", math.pow(base, exponent))

    elif choice == 5:
        angle = float(input("Enter angle in degrees: "))
        radians = math.radians(angle)
        print("sin =", math.sin(radians))

    elif choice == 6:
        angle = float(input("Enter angle in degrees: "))
        radians = math.radians(angle)
        print("cos =", math.cos(radians))

    elif choice == 7:
        angle = float(input("Enter angle in degrees: "))
        radians = math.radians(angle)
        print("tan =", math.tan(radians))

    elif choice == 8:
        a = int(input("Enter first number: "))
        b = int(input("Enter second number: "))
        print("GCD =", math.gcd(a, b))

    elif choice == 9:
        a = int(input("Enter first number: "))
        b = int(input("Enter second number: "))
        lcm = abs(a * b) // math.gcd(a, b)
        print("LCM =", lcm)

    elif choice == 10:
        print("Thank you for using the Scientific Calculator!")
        break

    else:
        print("Invalid choice! Please enter a number between 1 and 10.")
# Out:
# ===== Scientific Calculator =====
# 1. Square Root
# 2. Factorial
# 3. Logarithm (base 10)
# 4. Power
# 5. Sine
# 6. Cosine
# 7. Tangent
# 8. GCD
# 9. LCM
# 10. Exit
# Square Root = 4.69041575982343
#
# ===== Scientific Calculator =====
# 1. Square Root
# 2. Factorial
# 3. Logarithm (base 10)
# 4. Power
# 5. Sine
# 6. Cosine
# 7. Tangent
# 8. GCD
# 9. LCM
# 10. Exit
# Factorial = 8683317618811886495518194401280000000
#
# ===== Scientific Calculator =====
# 1. Square Root
# 2. Factorial
# 3. Logarithm (base 10)
# 4. Power
# 5. Sine
# 6. Cosine
# 7. Tangent
# 8. GCD
# 9. LCM
# 10. Exit
# Log(base 10) = 1.3424226808222062
#
# ===== Scientific Calculator =====
# 1. Square Root
# 2. Factorial
# 3. Logarithm (base 10)
# 4. Power
# 5. Sine
# 6. Cosine
# 7. Tangent
# 8. GCD
# 9. LCM
# 10. Exit
# Power = 1024.0
#
# ===== Scientific Calculator =====
# 1. Square Root
# 2. Factorial
# 3. Logarithm (base 10)
# 4. Power
# 5. Sine
# 6. Cosine
# 7. Tangent
# 8. GCD
# 9. LCM
# 10. Exit
# ...
